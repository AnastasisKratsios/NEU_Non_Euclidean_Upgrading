# %% [markdown]
# # NEU-Regressors

# %% [markdown]
# ---
# ## Outline of NEU:
#
# ---
#
# Get Training and Validation Sets: $\{x_n\}_{n\leq N} \to \{x_{n,t}\}_{n\leq N_1}, \{x_{n,v}\}_{n\leq N_2}$
#
# 1. Learn Feature Map:
#  For $i\leq \#$ of segment do:
#   - Train new feature map segment: $ \hat{\phi} \in \operatorname{argmin}_{\phi \in \operatorname{NN}_{\star:d;J} }
#    \sum_{n\leq N} w_n^{\star,\lambda}\,
#    L\left(f(x_n),A\phi\circ \hat{\phi}_i(x_n)+b,x_n\right) + P(A\phi\circ \hat{\phi}_i+b)$,
#   - Update feature map: $\phi_{i+1} = \hat{\phi}\circ \hat{\phi}_i$,
#   - Learn on Affine Model on partial training data: with current feature map: $\hat{A}_i,\hat{b}_i \in \operatorname{argmin}_{A,b}
#    \sum_{n\leq N} w_n^{\star,\lambda}\,
#    L\left(f(x_n),A\hat{\phi}_i(x_n)+b,x_n\right) + P(A\hat{\phi}_i+b)$,
# 2. Cross-Validate Feature Map Depth:
#   - Pick Depth $\hat{I}$ with best validation-error
#
# 3. Get full Model with NEU-Feature Map:
#
#   - $ \hat{f}^{NEU} \in \operatorname{argmin}_{\hat{f} \in \mathcal{F}}
#    \sum_{n\leq N} w_n^{\star,\lambda}\,
#    L\left(f(x_n),\hat{f}\circ \hat{\phi}_{\hat{I}}(x_n)+b,x_n\right) + P(\hat{f}\circ \hat{\phi}_{\hat{I}})$.
#
# **Return:** $\hat{f}^{NEU}$.
#
# ---
# ---
# ---

# %% [markdown]
# # What this script does?
# - Train NEU using different common regression models
# - Evaluate against benchmarks
#
#
# All this is done on synthetic data generated from the following types of functions:

# %% [markdown]
# ### Functions from the paper:
#  - 1) $\min\{\exp(\frac{-1}{(1+x)^2}),x+\cos(x)\}$. Reason: Evaluate performance for pasted functions and general badness.
#  - 2) $\cos(\exp(-x))$.  Reason: Evaluate performance for non-periodic osculations.
#  - 3) $I_{(-\infty,\frac1{2})}$.  Reason: Evaluation performance on a single jump.
#  - 4) Fractional Brownian Motion Realization
#
#  ---

# %% [markdown]
# # Generate Training Data

# %%
# First Round Initializations (Global Level) #
#============================================#
# Load Dependances and makes path(s)
exec(open('Initializations_Dump.py').read())
# Load Hyper( and meta) parameter(s)
exec(open('HyperParameter_Grid.py').read())
# %run Helper_Functions.ipynb
exec(open('Helper_Functions.py').read())
# Load Models
# %run Architecture_Builder.ipynb
exec(open('Architecture_Builder.py').read())
# Out:
# Parameter Grids Build and Loaded!
# Complete NEU-Structure Building Procedure!!!
# Complete NEU-Structure Building Procedure!!!
# Complete NEU-ffNN Training Procedure!!!
# Deep Feature Builder - Ready
# Complete NEU-ffNN Training Procedure!!!
# Complete NEU-ffNN Training Procedure!!!
# Complete NEU-ffNN (Fully Coupled) Training Procedure!!!
# Complete NEU-ffNN Training Procedure!!!
# Complete NEU-ffNN Training Procedure!!!

# %% [markdown]
# ### Fix Seeds for Reproducability

# %%
# Numpy
np.random.seed(2020)
# Tensorflow
tf.random.set_seed(2020)
# Python's Seed
random.seed(2020)

# %% [markdown]
# When generating data...you may use one of the following options:
# - For evaluating non-localy patterns: **"nonlocality"**
# - For evaluating model performance when faced with non-stationary osculatory behaviour: **"oscilatory"**
# - For evaluating jump-type performance when faced with a discontinuity: **"jumpdiscontinuity"**
# - For pattern which looks like noise/highly fractal-like/low Hölder regularity: **"rough"**
# - For fun/debugging/sanity checking: **"the_nightmare"**

# %%
#------------------------#
# Run External Notebooks #
#------------------------#
if Option_Function == "SnP":
    #--------------#
    # Get S&P Data #
    #--------------#
    #=# SnP Constituents #=#
    # Load Data
    snp_data = pd.read_csv('inputs/data/snp500_data/snp500-adjusted-close.csv')
    # Format Data
    ## Index by Time
    snp_data['date'] = pd.to_datetime(snp_data['date'],infer_datetime_format=True)
    snp_data.set_index('date', drop=True, inplace=True)
    snp_data.index.names = [None]
    #-------------------------------------------------------------------------------#
    
    #=# SnP Index #=#
    ## Read Regression Target
    snp_index_target_data = pd.read_csv('inputs/data/snp500_data/GSPC.csv')
    ## Get (Reference) Dates
    dates_temp = pd.to_datetime(snp_data['date'],infer_datetime_format=True).tail(600)
    ## Format Target
    snp_index_target_data = pd.DataFrame({'SnP_Index': snp_index_target_data['Close'],'date':dates_temp.reset_index(drop=True)})
    snp_index_target_data['date'] = pd.to_datetime(snp_index_target_data['date'],infer_datetime_format=True)
    snp_index_target_data.set_index('date', drop=True, inplace=True)
    snp_index_target_data.index.names = [None]
    #-------------------------------------------------------------------------------#
    
    ## Get Rid of NAs and Expired Trends
    snp_data = (snp_data.tail(600)).dropna(axis=1).fillna(0)
    # Get Return(s)
    snp_data_log_returns = snp_data.diff().iloc[1:]
    #--------------------------------------------------------#
    
    #-------------#
    # Subset Data #
    #-------------#
    # Get indices
    N_train_step = int(round(yield_data.shape[0]*Train_step_proportion,0))
    N_test_set = int(yield_data.shape[0] - round(yield_data.shape[0]*Train_step_proportion,0))
    # # Get Datasets
    X_train = yield_data[:N_train_step]
    X_test = yield_data[-N_test_set:]
    # Transpose
    X_train_T = X_train.T
    X_test_T = X_test.T


    # # Update User
    print('#================================================#')
    print(' Training Datasize: '+str(X_train.shape[0])+' and test datasize: ' + str(X_test.shape[0]) + '.  ')
    print('#================================================#')

    # # Set First Run to Off
    First_run = False

    #-----------#
    # Plot Data #
    #-----------#
    fig = snp_data_log_returns.plot(figsize=(16, 16))
    fig.get_legend().remove()
    plt.title("S&P Data Returns")

    # SAVE Figure to .eps
    plt.savefig('./outputs/plotsANDfigures/SNP_Data.pdf', format='pdf')
else:
    # Simulate Data using the data-generator:
    # %run Data_Generator.ipynb
    exec(open('Data_Generator.py').read())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-108-d2135802f167> in <module>
#      20     snp_index_target_data = pd.read_csv('inputs/data/snp500_data/GSPC.csv')
#      21     ## Get (Reference) Dates
# ---> 22     dates_temp = pd.to_datetime(snp_data['date'],infer_datetime_format=True).tail(600)
#      23     ## Format Target
#      24     snp_index_target_data = pd.DataFrame({'SnP_Index': snp_index_target_data['Close'],'date':dates_temp.reset_index(drop=True)})
#
# ~/.local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2897             if self.columns.nlevels > 1:
#    2898                 return self._getitem_multilevel(key)
# -> 2899             indexer = self.columns.get_loc(key)
#    2900             if is_integer(indexer):
#    2901                 indexer = [indexer]
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
# -> 2891                 raise KeyError(key) from err
#    2892
#    2893         if tolerance is not None:
#
# KeyError: 'date'

# %% [markdown]
# **TEMP:**
#
# Data Driven Robustness Rule:
# Using [this article](https://www.sciencedirect.com/science/article/pii/S0378375815000403) for the variance estimate.
# $$
# \hat{\sigma}^2 \triangleq
# \frac1{(n-1)}\sum_{1<n\leq N} (y_n - y_{n-1})^2
# .
# $$
#
# We couple it to the problem via the following
# $$
# \underset{\underset{0\leq w_n\leq 1}{\sum_{n\leq N} w_n=1}}{\operatorname{argmax}} \sum_{n\leq N} w_n L(f(x_n),\hat{f}(x_n),x_n) - \sigma^2 \sum_{n\leq N} w_n \ln\left(\frac{w_n}{N}\right)
# .
# $$

# %%
# GET STATISTICAL VARIANCE ESTIMATE
var_estimate = np.sum(np.diff(data_y)**2)/(((data_y.shape[0])-1))
var_estimate = np.float(round(var_estimate,3))


robustness_dictionary = {'robustness_parameter': [var_estimate*factor,var_estimate*2*factor,var_estimate*3*factor]}
#==================================================================================#        
### Create NEU parameter disctionary by parameters joining model it is upgrading ###
#==================================================================================#
param_grid_NEU_Nets = {**param_grid_NEU_Nets,
                       **robustness_dictionary}

param_grid_NEU_Feature_Only_Nets = {**param_grid_NEU_Feature_Only_Nets,
                                    **robustness_dictionary}

NEU_Structure_Dictionary = {**NEU_Structure_Dictionary,
                            **robustness_dictionary}

# NEU OLS Keys
param_grid_NEU_Reg_Nets = {**param_grid_NEU_Nets,
                           **robustness_dictionary}

param_grid_NEU_Reg_Nets.pop('height', None)
param_grid_NEU_Reg_Nets.pop('depth', None)
print(" ")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-bb2474f41053> in <module>
#       1 # GET STATISTICAL VARIANCE ESTIMATE
# ----> 2 var_estimate = np.sum(np.diff(data_y)**2)/(((data_y.shape[0])-1))
#       3 var_estimate = np.float(round(var_estimate,3))
#       4
#       5
#
# NameError: name 'data_y' is not defined

# %% [markdown]
# # Benchmark Models

# %% [markdown]
# Run univariate regression benchmarks file:

# %%
# %run Univariate_Regression_Benchmark_Models.ipynb
exec(open('Univariate_Regression_Benchmark_Models.py').read())
# Out:
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   2 out of   2 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=3)]: Done   2 out of   2 | elapsed:    0.6s finished
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=3)]: Done   2 out of   2 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=3)]: Done   2 out of   2 | elapsed:    0.7s finished
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   2 out of   2 | elapsed:    6.5s remaining:    0.0s
# [Parallel(n_jobs=3)]: Done   2 out of   2 | elapsed:    6.5s finished
# Epoch 1/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4787 - mse: 0.3570 - mae: 0.4787 - mape: 231.8707
# Epoch 2/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4265 - mse: 0.2826 - mae: 0.4265 - mape: 325.5012
# Epoch 3/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4062 - mse: 0.2671 - mae: 0.4062 - mape: 371.8918
# Epoch 4/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4068 - mse: 0.2694 - mae: 0.4068 - mape: 314.2791
# Epoch 5/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4048 - mse: 0.2634 - mae: 0.4048 - mape: 271.1327
# Epoch 6/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4050 - mse: 0.2640 - mae: 0.4050 - mape: 264.4569
# Epoch 7/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4021 - mse: 0.2624 - mae: 0.4021 - mape: 280.9156
# Epoch 8/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.
200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4019 - mse: 0.2632 - mae: 0.4019 - mape: 255.3984
# Epoch 191/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4031 - mse: 0.2639 - mae: 0.4031 - mape: 254.5381
# Epoch 192/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4021 - mse: 0.2633 - mae: 0.4021 - mape: 253.7366
# Epoch 193/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4018 - mse: 0.2633 - mae: 0.4018 - mape: 262.2314
# Epoch 194/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4027 - mse: 0.2639 - mae: 0.4027 - mape: 259.6165
# Epoch 195/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4023 - mse: 0.2630 - mae: 0.4023 - mape: 252.7306
# Epoch 196/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4026 - mse: 0.2643 - mae: 0.4026 - mape: 256.7341
# Epoch 197/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4019 - mse: 0.2640 - mae: 0.4019 - mape: 256.7179
# Epoch 198/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4033 - mse: 0.2647 - mae: 0.4033 - mape: 251.8666
# Epoch 199/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4021 - mse: 0.2630 - mae: 0.4021 - mape: 257.0895
# Epoch 200/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4023 - mse: 0.2631 - mae: 0.4023 - mape: 270.5683
# 8/8 [==============================] - 0s 942us/step
# 24/24 [==============================] - 0s 696us/step
# Benchmark-Model: Saving
# Benchmark-Model: Saved

# %% [markdown]
# ---
# # Train Feature Map for "decoupled" NEU-*Model(s)*
# ---

# %% [markdown]
# We train NEU's universal linearizing feature map.

# %%
tf.random.set_seed(2020)

start = time.time()
# 1+2) Learn Linearizing Feature Map #
#====================================#
# Obtain NEU-OLS predictions and Model
NEU_OLS_y_hat_train_pre, NEU_OLS_y_hat_test_pre, NEU_OLS, NEU_best_params = build_NEU_OLS(n_folds = CV_folds, 
                                                                                          n_jobs = n_jobs, 
                                                                                          n_iter = n_iter, 
                                                                                          param_grid_in = param_grid_NEU_Feature_Only_Nets, 
                                                                                          X_train = data_x, 
                                                                                          y_train = data_y,
                                                                                          X_test = data_x_test)
# Extract Linearizing Feature Map
Linearizing_Feature_Map = extract_trained_feature_map(NEU_OLS.model)

# Pre-process Linearized Data #
#========================b=====#
# Get Linearized Predictions #
#----------------------------#
data_x_featured_train = Linearizing_Feature_Map.predict(data_x)
data_x_featured_test = Linearizing_Feature_Map.predict(data_x_test)
# Coerce data into form ready for NEU-Structure Map
data_x_NEU_train = np.concatenate([data_x_featured_train,data_x.reshape(-1,D)],axis=1)
data_x_NEU_test = np.concatenate([data_x_featured_test,data_x_test.reshape(-1,D)],axis=1)


# Extract Feature Data Only (for De-coupled Implementations of Step 2) #
#----------------------------------------------------------------------#
data_x_NEU_train_feature_only = data_x_NEU_train[:,:d]
data_x_NEU_test_feature_only = data_x_NEU_test[:,:d]

#====================================#
# Ordinary Linear Regression Version #
#====================================#
# No Chaining
NEU_lin_reg_nochain = LinearRegression()
NEU_lin_reg_nochain.fit(data_x_featured_train,data_y)
NEU_OLS_train_nochain = NEU_lin_reg_nochain.predict(data_x_featured_train)
NEU_OLS_test_nochain = NEU_lin_reg_nochain.predict(data_x_featured_test)
# Out:
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   2 out of   2 | elapsed:   11.5s remaining:    0.0s
# [Parallel(n_jobs=3)]: Done   2 out of   2 | elapsed:   11.5s finished
# Epoch 1/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.7257 - mse: 0.4414 - mae: 0.5295 - mape: 177.8208
# Epoch 2/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6578 - mse: 0.3795 - mae: 0.4935 - mape: 258.0133
# Epoch 3/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5862 - mse: 0.3140 - mae: 0.4504 - mape: 301.2805
# Epoch 4/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.
50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5270 - mse: 0.2614 - mae: 0.4032 - mape: 306.9399
# Epoch 42/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5238 - mse: 0.2621 - mae: 0.4044 - mape: 292.3490
# Epoch 43/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5283 - mse: 0.2618 - mae: 0.4035 - mape: 296.0357
# Epoch 44/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5258 - mse: 0.2613 - mae: 0.4037 - mape: 310.6714
# Epoch 45/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5220 - mse: 0.2613 - mae: 0.4036 - mape: 313.7490
# Epoch 46/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5215 - mse: 0.2615 - mae: 0.4041 - mape: 319.9306
# Epoch 47/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5292 - mse: 0.2609 - mae: 0.4034 - mape: 318.3139
# Epoch 48/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5212 - mse: 0.2613 - mae: 0.4036 - mape: 312.0360
# Epoch 49/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5238 - mse: 0.2613 - mae: 0.4040 - mape: 327.1306
# Epoch 50/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5270 - mse: 0.2614 - mae: 0.4041 - mape: 321.0372
# 8/8 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# NEU-OLS: Trained!
# NEU-OLS: Saving
# NEU-OLS: Saved

# %% [markdown]
# ## Chaining Phase

# %% [markdown]
# #### Get Best Parameters for Chaining

# %%
Chaining_internalheight_per_block = NEU_best_params['feature_map_height']
Chaining_epochs_per_block = int(np.maximum(25,NEU_best_params['epochs']/N_chains))
Chaining_learning_rate_per_block = np.minimum(np.maximum(NEU_best_params['learning_rate']/N_chains,(10**(-8))),10**(-5))
Chaining_batchsize_per_block = NEU_best_params['batch_size']
Chaining_output_dimension = NEU_best_params['output_dim']
Feature_block_depth = int(np.maximum(5,NEU_best_params['feature_map_depth']))

# %%
#----------------------#
# Initialization Phase #
#----------------------#
# Initialize Best to Date
best_data_x_featured_train = data_x_featured_train
best_data_x_featured_test = data_x_featured_test
# Evaluate Feature Map Quanity (to date) #
#----------------------------------------#
# Get Internal Training/ Validation sub-sets
data_x_featured_train_internal, data_x_featured_validation_internal, y_train_internal, y_validation_internal = train_test_split(data_x_featured_train, data_y, test_size=0.33, random_state=42)
## Train NEU-OLS
NEU_lin_reg = LinearRegression()
NEU_lin_reg.fit(data_x_featured_train_internal,y_train_internal)
## Predict on Validation set
NEU_OLS_validation = NEU_lin_reg.predict(data_x_featured_validation_internal)
# Evaluate if validation loss improved
best_to_date_NEU_OLS_MAE = np.mean(np.abs(NEU_OLS_validation - y_validation_internal))
# Record Depth
best_n_chains = 0

#-==============-#
# Chaining Phase #
#-==============-#

for i_current_chain in range(N_chains):
    homotopy_parameter_loop = np.exp(i_current_chain)
    robustness_parameter_loop = (i_current_chain+1)/N_chains
    
    # Update User on Status #
    #-----------------------#
    print("=======================================================================")
    print("Performing " +str(i_current_chain)+"^th Feature Map Construction Step!")
    print("=======================================================================")
    
    # Performing Chained Feature Construction #
    #-----------------------------------------#
    data_x_featured_train, data_x_featured_test, Linearizing_Feature_Map = get_NEU_Feature_Chaining(learning_rate=Chaining_learning_rate_per_block, 
                                                                                                    X_train_in=data_x_NEU_train,
                                                                                                    X_test_in = data_x_NEU_test,
                                                                                                    y_train_in = data_y,
                                                                                                    block_depth = Feature_block_depth, 
                                                                                                    feature_map_height = Chaining_internalheight_per_block,
                                                                                                    robustness_parameter = robustness_parameter_loop, 
                                                                                                    homotopy_parameter = homotopy_parameter_loop,
                                                                                                    N_epochs = Chaining_epochs_per_block,
                                                                                                    batch_size = Chaining_batchsize_per_block,
                                                                                                    output_dim=Chaining_output_dimension)
    # Evaluate NEU #
    #--------------#
    # Get Internal Training/ Validation sub-sets
    data_x_featured_train_internal, data_x_featured_validation_internal, y_train_internal, y_validation_internal = train_test_split(data_x_featured_train, data_y, test_size=0.33, random_state=42)

    # Evalutate NEU-OLS
    ## Train
    NEU_lin_reg = LinearRegression()
    NEU_lin_reg.fit(data_x_featured_train_internal,y_train_internal)
    ## Predict on Validation set
    NEU_OLS_validation = NEU_lin_reg.predict(data_x_featured_validation_internal)
    # Evaluate if validation loss improved
    current_validation_NEU_OLS_MAE = np.mean(np.abs(NEU_OLS_validation - y_validation_internal))
    
    # Update "Best to date" features is there was a genuine improvement (only)! #
    #---------------------------------------------------------------------------#
    if current_validation_NEU_OLS_MAE < best_to_date_NEU_OLS_MAE:
        # Update Feature Map Predictions
        best_data_x_featured_train = data_x_featured_train
        best_data_x_featured_test = data_x_featured_test
        # Update N_chains Required
        best_n_chains = i_current_chain
    
    # Update User on Status #
    #-----------------------#
    print("=======================================================================")
    print("Completed " +str(i_current_chain)+"^th Feature Map Construction Step!")
    print("=======================================================================")
    print("Proportion of chains remaining: " +str(np.round(1-(i_current_chain+1)/N_chains,4)) + "...")
    print("=======================================================================")

# Update Feature Map with "Best"
data_x_featured_train = best_data_x_featured_train
data_x_featured_test = best_data_x_featured_test
    
# Record Depth Used
## Get "Best" hyperparameters
NEU_Feature_Map_w_Chaining = NEU_best_params
# Record NEU-Depth
NEU_Feature_Depth = (best_n_chains+NEU_Feature_Map_w_Chaining['feature_map_depth'])*Feature_block_depth
# Save Facts
print('NEU-Feature Map (w chaining): Saving')
NEU_Feature_Map_w_Chaining['Feature_Depth'] = NEU_Feature_Depth
NEU_Feature_Map_w_Chaining['N_Chains'] = int(best_n_chains+1)
NEU_Feature_Map_w_Chaining = pd.DataFrame.from_dict(NEU_Feature_Map_w_Chaining,orient='index')
Path('./outputs/models/NEU/NEU_OLS/').mkdir(parents=True, exist_ok=True)
NEU_Feature_Map_w_Chaining.to_latex("./outputs/models/NEU/NEU_OLS/NEU_feature_map_with_chaining_Best_Parameters.tex")
print('NEU-Feature Map (w chaining): Saved')

# Update User #
#-------------#
print(NEU_Feature_Map_w_Chaining)
NEU_Feature_Map_w_Chaining
# Out:
# =======================================================================
# Performing 0^th Feature Map Construction Step!
# =======================================================================
# Epoch 1/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6117 - mse: 0.5629 - mae: 0.6017
# Epoch 2/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6076 - mse: 0.5556 - mae: 0.5977
# Epoch 3/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6036 - mse: 0.5486 - mae: 0.5939
# Epoch 4/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5995 - mse: 0.5416 - mae: 0.5900
# Epoch 5/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5957 - mse: 0.5345 - mae: 0.5862
# Epoch 6/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5920 - mse: 0.5279 - mae: 0.5827
# Epoch 7/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5885 - mse: 0.5215 - mae: 0.5791
# Epoch 8/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5846 - mse: 0.5150 - mae: 0.5755
# Epoch 9/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5810 - mse: 0.5086 - mae: 0.5721
# Epoch 10/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5777 - mse: 0.5026 - mae: 0.5688
# Epoch 11/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5741 - mse: 0.4963 - mae: 0.5653
# Epoch 12/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5709 - mse: 0.4906 - mae: 0.5622
# Epoch 13/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5673 - mse: 0.4847 - mae: 0.5588
# Epoch 14/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5643 - mse: 0.4791 - mae: 0.5557
# Epoch 15/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5607 - mse: 0.4737 - mae: 0.5525
# Epoch 16/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5578 - mse: 0.4679 - mae: 0.5494
# Epoch 17/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5547 - mse: 0.4628 - mae: 0.5467
# Epoch 18/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5519 - mse: 0.4574 - mae: 0.5437
# Epoch 19/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5492 - mse: 0.4526 - mae: 0.5410
# Epoch 20/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5462 - mse: 0.4473 - mae: 0.5382
# Epoch 21/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5435 - mse: 0.4426 - mae: 0.5356
# Epoch 22/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5408 - mse: 0.4379 - mae: 0.5330
# Epoch 23/25
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5376 - mse: 0.4329 - mae: 0.5300
# Epoch 24/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5351 - mse: 0.4283 - mae: 0.5273
# Epoch 25/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5324 - mse: 0.4238 - mae: 0.5247
# =======================================================================
# Completed 0^th Feature Map Construction Step!
# =======================================================================
# Proportion of chains remaining: 0.95...
# =======================================================================
# =======================================================================
# Performing 1^th Feature Map Construction Step!
# =======================================================================
# Epoch 1/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5528 - mse: 0.4561 - mae: 0.5360
# Epoch 2/25
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5497 - mse: 0.4509 - mae: 0.5330
# Epoch 3/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5463 - mse: 0.4460 - mae: 0.5299
# Epoch 4/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5429 - mse: 0.4410 - mae: 0.5270
# Epoch 5/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5400 - mse: 0.4361 - mae: 0.5240
# Epoch 6/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5372 - mse: 0.4313 - mae: 0.5212
# Epoch 7/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5345 - mse: 0.4268 - mae: 0.5184
# Epoch 8/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5312 - mse: 0.4222 - mae: 0.5156
# Epoch 9/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5283 - mse: 0.4177 - mae: 0.5130
# Epoch 10/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5261 - mse: 0.4136 - mae: 0.5106
# Epoch 11/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5234 - mse: 0.4093 - mae: 0.5080
# Epoch 12/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5205 - mse: 0.4053 - mae: 0.5057
# Epoch 13/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5181 - mse: 0.4012 - mae: 0.5031
# Epoch 14/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5156 - mse: 0.3972 - mae: 0.5006
# Epoch 15/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5124 - mse: 0.3934 - mae: 0.4982
# Epoch 16/25
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5105 - mse: 0.3892 - mae: 0.4956
# Epoch 17/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5074 - mse: 0.3856 - mae: 0.4933
# Epoch 18/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5053 - mse: 0.3816 - mae: 0.4908
# Epoch 19/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5031 - mse: 0.3779 - mae: 0.4885
# Epoch 20/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5003 - mse: 0.3739 - mae: 0.4859
# Epoch 21/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.4979 - mse: 0.3703 - mae: 0.4836
# Epoch 22/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4956 - mse: 0.3667 - mae: 0.4813
# Epoch 23/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.4927 - mse: 0.3630 - mae: 0.4788
# Epoch 24/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.4906 - mse: 0.3596 - mae: 0.4766
# Epoch 25/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.4885 - mse: 0.3563 - mae: 0.4745
# =======================================================================
# Completed 1^th Feature Map Construction Step!
# =======================================================================
# Proportion of chains remaining: 0.9...
# =======================================================================
# =======================================================================
# Performing 2^th Feature Map Construction Step!
# =======================================================================
# Epoch 1/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.4964 - mse: 0.3602 - mae: 0.4764
# Epoch 2/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.4938 - mse: 0.3565 - mae: 0.4739
# Epoch 3/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.4911 - mse: 0.3530 - mae: 0.4715
# Epoch 4/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.4883 - mse: 0.3493 - mae: 0.4692
# Epoch 5/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.4861 - mse: 0.3459 - mae: 0.4669
# Epoch 6/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.4839 - mse: 0.3425 - mae: 0.4647
# Epoch 7/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.4818 - mse: 0.3393 - mae: 0.4626
# Epoch 8/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.4791 - mse: 0.3360 - mae: 0.4605
# Epoch 9/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.4768 - mse: 0.3327 - mae: 0.4583
# Epoch 10/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.4751 - mse: 0.3298 - mae: 0.4564
# Epoch 11/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.4728 - mse: 0.3267 - mae: 0.4543
# Epoch 12/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.4702 - mse: 0.3238 - mae: 0.4523
# Epoch 13/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.4683 - mse: 0.3208 - mae: 0.4501
# Epoch 14/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.4663 - mse: 0.3181 - mae: 0.4482
# Epoch 15/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.4638 - mse: 0.3153 - mae: 0.4463
# Epoch 16/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.4625 - mse: 0.3124 - mae: 0.4444
# Epoch 17/25
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4600 - mse: 0.3101 - mae: 0.4429
# Epoch 18/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4588 - mse: 0.3076 - mae: 0.4411
# Epoch 19/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4574 - mse: 0.3054 - mae: 0.4396
# Epoch 20/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4553 - mse: 0.3028 - mae: 0.4378
# Epoch 21/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4537 - mse: 0.3006 - mae: 0.4361
# Epoch 22/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.4521 - mse: 0.2986 - mae: 0.4347
# Epoch 23/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4499 - mse: 0.2962 - mae: 0.4329
# Epoch 24/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4484 - mse: 0.2940 - mae: 0.4311
# Epoch 25/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.4467 - mse: 0.2922 - mae: 0.4297
# =======================================================================
# Completed 2^th Feature Map Construction Step!
# =======================================================================
# Proportion of chains remaining: 0.85...
# =======================================================================
# =======================================================================
# Performing 3^th Feature Map Construction Step!
# =======================================================================
# Epoch 1/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6063 - mse: 0.5093 - mae: 0.5686
# Epoch 2/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6028 - mse: 0.5038 - mae: 0.5653
# Epoch 3/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5991 - mse: 0.4985 - mae: 0.5622
# Epoch 4/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5953 - mse: 0.4932 - mae: 0.5592
# Epoch 5/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5925 - mse: 0.4880 - mae: 0.5562
# Epoch 6/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5894 - mse: 0.4830 - mae: 0.5534
# Epoch 7/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5868 - mse: 0.4781 - mae: 0.5504
# Epoch 8/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5828 - mse: 0.4731 - mae: 0.5475
# Epoch 9/25
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5792 - mse: 0.4683 - mae: 0.5446
# Epoch 10/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5769 - mse: 0.4638 - mae: 0.5420
# Epoch 11/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5739 - mse: 0.4590 - mae: 0.5393
# Epoch 12/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5706 - mse: 0.4548 - mae: 0.5370
# Epoch 13/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5678 - mse: 0.4502 - mae: 0.5344
# Epoch 14/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5654 - mse: 0.4460 - mae: 0.5319
# Epoch 15/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5609 - mse: 0.4418 - mae: 0.5294
# Epoch 16/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5597 - mse: 0.4373 - mae: 0.5268
# Epoch 17/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5557 - mse: 0.4332 - mae: 0.5245
# Epoch 18/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5540 - mse: 0.4288 - mae: 0.5219
# Epoch 19/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5515 - mse: 0.4248 - mae: 0.5196
# Epoch 20/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5484 - mse: 0.4203 - mae: 0.5169
# Epoch 21/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5457 - mse: 0.4162 - mae: 0.5145
# Epoch 22/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5429 - mse: 0.4121 - mae: 0.5121
# Epoch 23/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5394 - mse: 0.4079 - mae: 0.5095
# Epoch 24/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5373 - mse: 0.4039 - mae: 0.5071
# Epoch 25/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5347 - mse: 0.4001 - mae: 0.5048
# =======================================================================
# Completed 3^th Feature Map Construction Step!
# =======================================================================
# Proportion of chains remaining: 0.8...
# =======================================================================
# =======================================================================
# Performing 4^th Feature Map Construction Step!
# =======================================================================
# Epoch 1/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5726 - mse: 0.4471 - mae: 0.5306
# Epoch 2/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5696 - mse: 0.4422 - mae: 0.5277
# Epoch 3/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5660 - mse: 0.4377 - mae: 0.5248
# Epoch 4/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5623 - mse: 0.4331 - mae: 0.5220
# Epoch 5/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5596 - mse: 0.4287 - mae: 0.5192
# Epoch 6/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5571 - mse: 0.4244 - mae: 0.5166
# Epoch 7/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5548 - mse: 0.4203 - mae: 0.5141
# Epoch 8/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5507 - mse: 0.4161 - mae: 0.5114
# Epoch 9/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5474 - mse: 0.4120 - mae: 0.5089
# Epoch 10/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5457 - mse: 0.4081 - mae: 0.5065
# Epoch 11/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5426 - mse: 0.4040 - mae: 0.5039
# Epoch 12/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5386 - mse: 0.4002 - mae: 0.5015
# Epoch 13/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5367 - mse: 0.3962 - mae: 0.4990
# Epoch 14/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5338 - mse: 0.3925 - mae: 0.4965
# Epoch 15/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5297 - mse: 0.3889 - mae: 0.4942
# Epoch 16/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5288 - mse: 0.3849 - mae: 0.4917
# Epoch 17/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5244 - mse: 0.3814 - mae: 0.4895
# Epoch 18/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5229 - mse: 0.3776 - mae: 0.4870
# Epoch 19/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5209 - mse: 0.3741 - mae: 0.4848
# Epoch 20/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5177 - mse: 0.3702 - mae: 0.4824
# Epoch 21/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5153 - mse: 0.3668 - mae: 0.4802
# Epoch 22/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5128 - mse: 0.3634 - mae: 0.4780
# Epoch 23/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5095 - mse: 0.3598 - mae: 0.4756
# Epoch 24/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5076 - mse: 0.3564 - mae: 0.4734
# Epoch 25/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5049 - mse: 0.3531 - mae: 0.4712
# =======================================================================
# Completed 4^th Feature Map Construction Step!
# =======================================================================
# Proportion of chains remaining: 0.75...
# =======================================================================
# =======================================================================
# Performing 5^th Feature Map Construction Step!
# =======================================================================
# Epoch 1/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5740 - mse: 0.4360 - mae: 0.5244
# Epoch 2/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5707 - mse: 0.4310 - mae: 0.5215
# Epoch 3/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5670 - mse: 0.4263 - mae: 0.5187
# Epoch 4/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5630 - mse: 0.4216 - mae: 0.5160
# Epoch 5/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5603 - mse: 0.4169 - mae: 0.5132
# Epoch 6/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5574 - mse: 0.4124 - mae: 0.5106
# Epoch 7/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5550 - mse: 0.4080 - mae: 0.5079
# Epoch 8/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5505 - mse: 0.4035 - mae: 0.5052
# Epoch 9/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5470 - mse: 0.3990 - mae: 0.5025
# Epoch 10/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5449 - mse: 0.3948 - mae: 0.5000
# Epoch 11/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5414 - mse: 0.3903 - mae: 0.4971
# Epoch 12/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5373 - mse: 0.3862 - mae: 0.4946
# Epoch 13/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5348 - mse: 0.3819 - mae: 0.4919
# Epoch 14/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5319 - mse: 0.3779 - mae: 0.4893
# Epoch 15/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5272 - mse: 0.3740 - mae: 0.4868
# Epoch 16/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5262 - mse: 0.3698 - mae: 0.4841
# Epoch 17/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5212 - mse: 0.3660 - mae: 0.4817
# Epoch 18/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5199 - mse: 0.3619 - mae: 0.4790
# Epoch 19/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5175 - mse: 0.3583 - mae: 0.4768
# Epoch 20/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5142 - mse: 0.3543 - mae: 0.4742
# Epoch 21/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5116 - mse: 0.3507 - mae: 0.4718
# Epoch 22/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5089 - mse: 0.3472 - mae: 0.4695
# Epoch 23/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5049 - mse: 0.3434 - mae: 0.4669
# Epoch 24/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5031 - mse: 0.3399 - mae: 0.4646
# Epoch 25/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5004 - mse: 0.3366 - mae: 0.4625
# =======================================================================
# Completed 5^th Feature Map Construction Step!
# =======================================================================
# Proportion of chains remaining: 0.7...
# =======================================================================
# =======================================================================
# Performing 6^th Feature Map Construction Step!
# =======================================================================
# Epoch 1/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.7227 - mse: 0.6398 - mae: 0.6382
# Epoch 2/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.7185 - mse: 0.6327 - mae: 0.6343
# Epoch 3/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.7132 - mse: 0.6260 - mae: 0.6307
# Epoch 4/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.7081 - mse: 0.6193 - mae: 0.6271
# Epoch 5/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.7042 - mse: 0.6124 - mae: 0.6234
# Epoch 6/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.7008 - mse: 0.6058 - mae: 0.6199
# Epoch 7/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6977 - mse: 0.5994 - mae: 0.6164
# Epoch 8/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6917 - mse: 0.5929 - mae: 0.6129
# Epoch 9/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6864 - mse: 0.5864 - mae: 0.6095
# Epoch 10/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6841 - mse: 0.5803 - mae: 0.6064
# Epoch 11/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6795 - mse: 0.5738 - mae: 0.6029
# Epoch 12/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6745 - mse: 0.5679 - mae: 0.5998
# Epoch 13/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6705 - mse: 0.5615 - mae: 0.5963
# Epoch 14/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.6669 - mse: 0.5556 - mae: 0.5931
# Epoch 15/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6591 - mse: 0.5497 - mae: 0.5898
# Epoch 16/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6590 - mse: 0.5433 - mae: 0.5865
# Epoch 17/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6525 - mse: 0.5376 - mae: 0.5833
# Epoch 18/25
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6509 - mse: 0.5314 - mae: 0.5800
# Epoch 19/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6472 - mse: 0.5257 - mae: 0.5768
# Epoch 20/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6428 - mse: 0.5194 - mae: 0.5733
# Epoch 21/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6384 - mse: 0.5136 - mae: 0.5699
# Epoch 22/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6340 - mse: 0.5078 - mae: 0.5665
# Epoch 23/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.6292 - mse: 0.5017 - mae: 0.5629
# Epoch 24/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6262 - mse: 0.4959 - mae: 0.5596
# Epoch 25/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.6220 - mse: 0.4902 - mae: 0.5563
# =======================================================================
# Completed 6^th Feature Map Construction Step!
# =======================================================================
# Proportion of chains remaining: 0.65...
# =======================================================================
# =======================================================================
# Performing 7^th Feature Map Construction Step!
# =======================================================================
# Epoch 1/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6460 - mse: 0.5106 - mae: 0.5677
# Epoch 2/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6430 - mse: 0.5059 - mae: 0.5650
# Epoch 3/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6391 - mse: 0.5013 - mae: 0.5623
# Epoch 4/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6346 - mse: 0.4968 - mae: 0.5596
# Epoch 5/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6320 - mse: 0.4922 - mae: 0.5570
# Epoch 6/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6299 - mse: 0.4879 - mae: 0.5545
# Epoch 7/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6278 - mse: 0.4836 - mae: 0.5519
# Epoch 8/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6228 - mse: 0.4793 - mae: 0.5492
# Epoch 9/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6187 - mse: 0.4750 - mae: 0.5468
# Epoch 10/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.6178 - mse: 0.4710 - mae: 0.5444
# Epoch 11/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.6142 - mse: 0.4668 - mae: 0.5419
# Epoch 12/25
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6094 - mse: 0.4629 - mae: 0.5396
# Epoch 13/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6077 - mse: 0.4589 - mae: 0.5371
# Epoch 14/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6048 - mse: 0.4550 - mae: 0.5349
# Epoch 15/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5985 - mse: 0.4513 - mae: 0.5325
# Epoch 16/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5998 - mse: 0.4472 - mae: 0.5302
# Epoch 17/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5939 - mse: 0.4436 - mae: 0.5280
# Epoch 18/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5938 - mse: 0.4398 - mae: 0.5258
# Epoch 19/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5915 - mse: 0.4362 - mae: 0.5236
# Epoch 20/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5881 - mse: 0.4323 - mae: 0.5212
# Epoch 21/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5855 - mse: 0.4287 - mae: 0.5190
# Epoch 22/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5825 - mse: 0.4251 - mae: 0.5169
# Epoch 23/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5787 - mse: 0.4214 - mae: 0.5146
# Epoch 24/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5774 - mse: 0.4178 - mae: 0.5124
# Epoch 25/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5745 - mse: 0.4144 - mae: 0.5104
# =======================================================================
# Completed 7^th Feature Map Construction Step!
# =======================================================================
# Proportion of chains remaining: 0.6...
# =======================================================================
# =======================================================================
# Performing 8^th Feature Map Construction Step!
# =======================================================================
# Epoch 1/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5937 - mse: 0.4288 - mae: 0.5194
# Epoch 2/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5899 - mse: 0.4233 - mae: 0.5161
# Epoch 3/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5851 - mse: 0.4181 - mae: 0.5128
# Epoch 4/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5798 - mse: 0.4129 - mae: 0.5096
# Epoch 5/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5763 - mse: 0.4078 - mae: 0.5063
# Epoch 6/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5735 - mse: 0.4029 - mae: 0.5032
# Epoch 7/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5707 - mse: 0.3982 - mae: 0.5002
# Epoch 8/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5647 - mse: 0.3935 - mae: 0.4971
# Epoch 9/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5605 - mse: 0.3888 - mae: 0.4942
# Epoch 10/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5591 - mse: 0.3846 - mae: 0.4915
# Epoch 11/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5551 - mse: 0.3802 - mae: 0.4887
# Epoch 12/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5493 - mse: 0.3761 - mae: 0.4861
# Epoch 13/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5479 - mse: 0.3720 - mae: 0.4834
# Epoch 14/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5442 - mse: 0.3681 - mae: 0.4808
# Epoch 15/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5392 - mse: 0.3644 - mae: 0.4785
# Epoch 16/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5396 - mse: 0.3604 - mae: 0.4760
# Epoch 17/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5329 - mse: 0.3570 - mae: 0.4738
# Epoch 18/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5326 - mse: 0.3533 - mae: 0.4713
# Epoch 19/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5307 - mse: 0.3500 - mae: 0.4692
# Epoch 20/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5267 - mse: 0.3463 - mae: 0.4667
# Epoch 21/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5246 - mse: 0.3431 - mae: 0.4645
# Epoch 22/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5220 - mse: 0.3400 - mae: 0.4625
# Epoch 23/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5176 - mse: 0.3368 - mae: 0.4603
# Epoch 24/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5166 - mse: 0.3337 - mae: 0.4581
# Epoch 25/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5135 - mse: 0.3308 - mae: 0.4562
# =======================================================================
# Completed 8^th Feature Map Construction Step!
# =======================================================================
# Proportion of chains remaining: 0.55...
# =======================================================================
# =======================================================================
# Performing 9^th Feature Map Construction Step!
# =======================================================================
# Epoch 1/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6317 - mse: 0.4644 - mae: 0.5416
# Epoch 2/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6276 - mse: 0.4588 - mae: 0.5385
# Epoch 3/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6229 - mse: 0.4534 - mae: 0.5353
# Epoch 4/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6175 - mse: 0.4481 - mae: 0.5322
# Epoch 5/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6145 - mse: 0.4427 - mae: 0.5291
# Epoch 6/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6110 - mse: 0.4376 - mae: 0.5263
# Epoch 7/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6086 - mse: 0.4326 - mae: 0.5233
# Epoch 8/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6024 - mse: 0.4276 - mae: 0.5204
# Epoch 9/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5979 - mse: 0.4227 - mae: 0.5175
# Epoch 10/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5961 - mse: 0.4181 - mae: 0.5148
# Epoch 11/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5918 - mse: 0.4132 - mae: 0.5119
# Epoch 12/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5865 - mse: 0.4088 - mae: 0.5093
# Epoch 13/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5837 - mse: 0.4042 - mae: 0.5065
# Epoch 14/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5805 - mse: 0.3999 - mae: 0.5038
# Epoch 15/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5737 - mse: 0.3957 - mae: 0.5012
# Epoch 16/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5743 - mse: 0.3913 - mae: 0.4985
# Epoch 17/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5670 - mse: 0.3873 - mae: 0.4961
# Epoch 18/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5672 - mse: 0.3831 - mae: 0.4934
# Epoch 19/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5644 - mse: 0.3793 - mae: 0.4910
# Epoch 20/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5604 - mse: 0.3750 - mae: 0.4883
# Epoch 21/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5578 - mse: 0.3713 - mae: 0.4859
# Epoch 22/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5545 - mse: 0.3676 - mae: 0.4836
# Epoch 23/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5492 - mse: 0.3637 - mae: 0.4810
# Epoch 24/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5481 - mse: 0.3600 - mae: 0.4786
# Epoch 25/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5449 - mse: 0.3566 - mae: 0.4765
# =======================================================================
# Completed 9^th Feature Map Construction Step!
# =======================================================================
# Proportion of chains remaining: 0.5...
# =======================================================================
# =======================================================================
# Performing 10^th Feature Map Construction Step!
# =======================================================================
# Epoch 1/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6845 - mse: 0.5200 - mae: 0.5733
# Epoch 2/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6813 - mse: 0.5148 - mae: 0.5703
# Epoch 3/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6765 - mse: 0.5099 - mae: 0.5675
# Epoch 4/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6710 - mse: 0.5049 - mae: 0.5645
# Epoch 5/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6677 - mse: 0.4999 - mae: 0.5616
# Epoch 6/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6659 - mse: 0.4950 - mae: 0.5588
# Epoch 7/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6637 - mse: 0.4903 - mae: 0.5560
# Epoch 8/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6570 - mse: 0.4854 - mae: 0.5530
# Epoch 9/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6518 - mse: 0.4805 - mae: 0.5502
# Epoch 10/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6515 - mse: 0.4760 - mae: 0.5476
# Epoch 11/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.6467 - mse: 0.4712 - mae: 0.5446
# Epoch 12/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.6401 - mse: 0.4667 - mae: 0.5420
# Epoch 13/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6384 - mse: 0.4620 - mae: 0.5392
# Epoch 14/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6344 - mse: 0.4575 - mae: 0.5365
# Epoch 15/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.6262 - mse: 0.4530 - mae: 0.5337
# Epoch 16/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.6287 - mse: 0.4482 - mae: 0.5309
# Epoch 17/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6202 - mse: 0.4439 - mae: 0.5284
# Epoch 18/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6206 - mse: 0.4393 - mae: 0.5256
# Epoch 19/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6176 - mse: 0.4349 - mae: 0.5229
# Epoch 20/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6126 - mse: 0.4301 - mae: 0.5199
# Epoch 21/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.6095 - mse: 0.4257 - mae: 0.5171
# Epoch 22/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6056 - mse: 0.4213 - mae: 0.5144
# Epoch 23/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6002 - mse: 0.4166 - mae: 0.5115
# Epoch 24/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5987 - mse: 0.4122 - mae: 0.5087
# Epoch 25/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5942 - mse: 0.4079 - mae: 0.5061
# =======================================================================
# Completed 10^th Feature Map Construction Step!
# =======================================================================
# Proportion of chains remaining: 0.45...
# =======================================================================
# =======================================================================
# Performing 11^th Feature Map Construction Step!
# =======================================================================
# Epoch 1/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5787 - mse: 0.3804 - mae: 0.4892
# Epoch 2/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5755 - mse: 0.3764 - mae: 0.4866
# Epoch 3/25
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5714 - mse: 0.3725 - mae: 0.4841
# Epoch 4/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5663 - mse: 0.3685 - mae: 0.4817
# Epoch 5/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5638 - mse: 0.3647 - mae: 0.4791
# Epoch 6/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5617 - mse: 0.3609 - mae: 0.4767
# Epoch 7/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5595 - mse: 0.3573 - mae: 0.4743
# Epoch 8/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5535 - mse: 0.3536 - mae: 0.4719
# Epoch 9/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5500 - mse: 0.3499 - mae: 0.4694
# Epoch 10/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5495 - mse: 0.3466 - mae: 0.4673
# Epoch 11/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5455 - mse: 0.3430 - mae: 0.4650
# Epoch 12/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5393 - mse: 0.3398 - mae: 0.4628
# Epoch 13/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5389 - mse: 0.3364 - mae: 0.4604
# Epoch 14/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5352 - mse: 0.3333 - mae: 0.4583
# Epoch 15/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5310 - mse: 0.3302 - mae: 0.4562
# Epoch 16/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5321 - mse: 0.3270 - mae: 0.4541
# Epoch 17/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5243 - mse: 0.3243 - mae: 0.4523
# Epoch 18/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5253 - mse: 0.3213 - mae: 0.4503
# Epoch 19/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5242 - mse: 0.3187 - mae: 0.4486
# Epoch 20/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5201 - mse: 0.3157 - mae: 0.4466
# Epoch 21/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5189 - mse: 0.3133 - mae: 0.4447
# Epoch 22/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5166 - mse: 0.3109 - mae: 0.4432
# Epoch 23/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5119 - mse: 0.3083 - mae: 0.4414
# Epoch 24/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5118 - mse: 0.3058 - mae: 0.4395
# Epoch 25/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5086 - mse: 0.3036 - mae: 0.4380
# =======================================================================
# Completed 11^th Feature Map Construction Step!
# =======================================================================
# Proportion of chains remaining: 0.4...
# =======================================================================
# =======================================================================
# Performing 12^th Feature Map Construction Step!
# =======================================================================
# Epoch 1/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6379 - mse: 0.4368 - mae: 0.5245
# Epoch 2/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6338 - mse: 0.4321 - mae: 0.5217
# Epoch 3/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6290 - mse: 0.4276 - mae: 0.5188
# Epoch 4/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6232 - mse: 0.4231 - mae: 0.5162
# Epoch 5/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6206 - mse: 0.4185 - mae: 0.5135
# Epoch 6/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6179 - mse: 0.4142 - mae: 0.5110
# Epoch 7/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6160 - mse: 0.4099 - mae: 0.5084
# Epoch 8/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6090 - mse: 0.4055 - mae: 0.5057
# Epoch 9/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6046 - mse: 0.4011 - mae: 0.5031
# Epoch 10/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6039 - mse: 0.3971 - mae: 0.5006
# Epoch 11/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5990 - mse: 0.3927 - mae: 0.4979
# Epoch 12/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5925 - mse: 0.3887 - mae: 0.4954
# Epoch 13/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5908 - mse: 0.3845 - mae: 0.4926
# Epoch 14/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5870 - mse: 0.3805 - mae: 0.4900
# Epoch 15/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5797 - mse: 0.3766 - mae: 0.4876
# Epoch 16/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5817 - mse: 0.3725 - mae: 0.4849
# Epoch 17/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5723 - mse: 0.3689 - mae: 0.4826
# Epoch 18/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5739 - mse: 0.3649 - mae: 0.4800
# Epoch 19/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5713 - mse: 0.3613 - mae: 0.4778
# Epoch 20/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5667 - mse: 0.3573 - mae: 0.4752
# Epoch 21/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5646 - mse: 0.3537 - mae: 0.4729
# Epoch 22/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5610 - mse: 0.3503 - mae: 0.4706
# Epoch 23/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5548 - mse: 0.3466 - mae: 0.4681
# Epoch 24/25
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5544 - mse: 0.3430 - mae: 0.4658
# Epoch 25/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5505 - mse: 0.3397 - mae: 0.4637
# =======================================================================
# Completed 12^th Feature Map Construction Step!
# =======================================================================
# Proportion of chains remaining: 0.35...
# =======================================================================
# =======================================================================
# Performing 13^th Feature Map Construction Step!
# =======================================================================
# Epoch 1/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6427 - mse: 0.4309 - mae: 0.5207
# Epoch 2/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6384 - mse: 0.4267 - mae: 0.5182
# Epoch 3/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6334 - mse: 0.4228 - mae: 0.5157
# Epoch 4/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6274 - mse: 0.4188 - mae: 0.5133
# Epoch 5/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6246 - mse: 0.4149 - mae: 0.5108
# Epoch 6/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6233 - mse: 0.4111 - mae: 0.5085
# Epoch 7/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.6217 - mse: 0.4073 - mae: 0.5061
# Epoch 8/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6146 - mse: 0.4035 - mae: 0.5035
# Epoch 9/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6103 - mse: 0.3997 - mae: 0.5012
# Epoch 10/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6109 - mse: 0.3962 - mae: 0.4990
# Epoch 11/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6063 - mse: 0.3925 - mae: 0.4967
# Epoch 12/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5991 - mse: 0.3891 - mae: 0.4945
# Epoch 13/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5993 - mse: 0.3855 - mae: 0.4923
# Epoch 14/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5949 - mse: 0.3821 - mae: 0.4900
# Epoch 15/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5884 - mse: 0.3788 - mae: 0.4880
# Epoch 16/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5920 - mse: 0.3753 - mae: 0.4858
# Epoch 17/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5820 - mse: 0.3722 - mae: 0.4839
# Epoch 18/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5843 - mse: 0.3688 - mae: 0.4816
# Epoch 19/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5825 - mse: 0.3657 - mae: 0.4797
# Epoch 20/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5776 - mse: 0.3623 - mae: 0.4775
# Epoch 21/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5763 - mse: 0.3592 - mae: 0.4755
# Epoch 22/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5732 - mse: 0.3562 - mae: 0.4735
# Epoch 23/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5673 - mse: 0.3530 - mae: 0.4713
# Epoch 24/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5676 - mse: 0.3499 - mae: 0.4692
# Epoch 25/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5633 - mse: 0.3470 - mae: 0.4674
# =======================================================================
# Completed 13^th Feature Map Construction Step!
# =======================================================================
# Proportion of chains remaining: 0.3...
# =======================================================================
# =======================================================================
# Performing 14^th Feature Map Construction Step!
# =======================================================================
# Epoch 1/25
# 8/8 [==============================] - 0s 14ms/step - loss: 0.6028 - mse: 0.3725 - mae: 0.4845
# Epoch 2/25
# 8/8 [==============================] - 0s 14ms/step - loss: 0.
# 8/8 [==============================] - 0s 15ms/step - loss: 0.5372 - mse: 0.3041 - mae: 0.4430
# =======================================================================
# Completed 15^th Feature Map Construction Step!
# =======================================================================
# Proportion of chains remaining: 0.2...
# =======================================================================
# =======================================================================
# Performing 16^th Feature Map Construction Step!
# =======================================================================
# Epoch 1/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.8937 - mse: 0.6159 - mae: 0.6275
# Epoch 2/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.8553 - mse: 0.6090 - mae: 0.6237
# Epoch 3/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.8342 - mse: 0.6024 - mae: 0.6203
# Epoch 4/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.8211 - mse: 0.5959 - mae: 0.6169
# Epoch 5/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.8149 - mse: 0.5892 - mae: 0.6134
# Epoch 6/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.8104 - mse: 0.5829 - mae: 0.6101
# Epoch 7/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.8080 - mse: 0.5768 - mae: 0.6068
# Epoch 8/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.7965 - mse: 0.5705 - mae: 0.6034
# Epoch 9/25
# 8/8 [==============================] - 0s 14ms/step - loss: 0.7902 - mse: 0.5643 - mae: 0.6002
# Epoch 10/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.7886 - mse: 0.5585 - mae: 0.5971
# Epoch 11/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.7824 - mse: 0.5524 - mae: 0.5938
# Epoch 12/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.7753 - mse: 0.5468 - mae: 0.5907
# Epoch 13/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.7679 - mse: 0.5408 - mae: 0.5874
# Epoch 14/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.7648 - mse: 0.5353 - mae: 0.5844
# Epoch 15/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.7501 - mse: 0.5298 - mae: 0.5813
# Epoch 16/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.7571 - mse: 0.5240 - mae: 0.5780
# Epoch 17/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.7434 - mse: 0.5187 - mae: 0.5751
# Epoch 18/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.7482 - mse: 0.5131 - mae: 0.5720
# Epoch 19/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.7430 - mse: 0.5079 - mae: 0.5690
# Epoch 20/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.7371 - mse: 0.5022 - mae: 0.5658
# Epoch 21/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.7339 - mse: 0.4971 - mae: 0.5629
# Epoch 22/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.7270 - mse: 0.4919 - mae: 0.5600
# Epoch 23/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.7194 - mse: 0.4865 - mae: 0.5569
# Epoch 24/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.7189 - mse: 0.4813 - mae: 0.5540
# Epoch 25/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.7137 - mse: 0.4763 - mae: 0.5512
# =======================================================================
# Completed 16^th Feature Map Construction Step!
# =======================================================================
# Proportion of chains remaining: 0.15...
# =======================================================================
# =======================================================================
# Performing 17^th Feature Map Construction Step!
# =======================================================================
# Epoch 1/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.7651 - mse: 0.3600 - mae: 0.4761
# Epoch 2/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6703 - mse: 0.3564 - mae: 0.4736
# Epoch 3/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6282 - mse: 0.3528 - mae: 0.4713
# Epoch 4/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6021 - mse: 0.3493 - mae: 0.4691
# Epoch 5/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5977 - mse: 0.3459 - mae: 0.4667
# Epoch 6/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5914 - mse: 0.3426 - mae: 0.4645
# Epoch 7/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5892 - mse: 0.3395 - mae: 0.4624
# Epoch 8/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5808 - mse: 0.3362 - mae: 0.4603
# Epoch 9/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5773 - mse: 0.3331 - mae: 0.4581
# Epoch 10/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5781 - mse: 0.3302 - mae: 0.4562
# Epoch 11/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5728 - mse: 0.3272 - mae: 0.4541
# Epoch 12/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5649 - mse: 0.3245 - mae: 0.4523
# Epoch 13/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5667 - mse: 0.3216 - mae: 0.4501
# Epoch 14/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5622 - mse: 0.3190 - mae: 0.4485
# Epoch 15/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5584 - mse: 0.3166 - mae: 0.4468
# Epoch 16/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5613 - mse: 0.3140 - mae: 0.4452
# Epoch 17/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5500 - mse: 0.3118 - mae: 0.4437
# Epoch 18/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5538 - mse: 0.3094 - mae: 0.4420
# Epoch 19/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5537 - mse: 0.3073 - mae: 0.4406
# Epoch 20/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5487 - mse: 0.3048 - mae: 0.4388
# Epoch 21/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5489 - mse: 0.3028 - mae: 0.4372
# Epoch 22/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5464 - mse: 0.3009 - mae: 0.4360
# Epoch 23/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.5403 - mse: 0.2988 - mae: 0.4345
# Epoch 24/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5423 - mse: 0.2968 - mae: 0.4329
# Epoch 25/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5382 - mse: 0.2951 - mae: 0.4316
# =======================================================================
# Completed 17^th Feature Map Construction Step!
# =======================================================================
# Proportion of chains remaining: 0.1...
# =======================================================================
# =======================================================================
# Performing 18^th Feature Map Construction Step!
# =======================================================================
# Epoch 1/25
# 8/8 [==============================] - 0s 11ms/step - loss: 1.2084 - mse: 0.5275 - mae: 0.5774
# Epoch 2/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.9584 - mse: 0.5212 - mae: 0.5738
# Epoch 3/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.8491 - mse: 0.5152 - mae: 0.5704
# Epoch 4/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.7876 - mse: 0.5092 - mae: 0.5670
# Epoch 5/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.7751 - mse: 0.5031 - mae: 0.5634
# Epoch 6/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.7608 - mse: 0.4973 - mae: 0.5601
# Epoch 7/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.7570 - mse: 0.4917 - mae: 0.5568
# Epoch 8/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.7428 - mse: 0.4860 - mae: 0.5534
# Epoch 9/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.7359 - mse: 0.4803 - mae: 0.5502
# Epoch 10/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.7356 - mse: 0.4750 - mae: 0.5471
# Epoch 11/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.7279 - mse: 0.4694 - mae: 0.5437
# Epoch 12/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.7188 - mse: 0.4643 - mae: 0.5407
# Epoch 13/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.7149 - mse: 0.4589 - mae: 0.5375
# Epoch 14/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.7098 - mse: 0.4538 - mae: 0.5346
# Epoch 15/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6961 - mse: 0.4489 - mae: 0.5316
# Epoch 16/25
# 8/8 [==============================] - 0s 10ms/step - loss: 0.7039 - mse: 0.4436 - mae: 0.5287
# Epoch 17/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6882 - mse: 0.4389 - mae: 0.5260
# Epoch 18/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6939 - mse: 0.4339 - mae: 0.5231
# Epoch 19/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6890 - mse: 0.4292 - mae: 0.5204
# Epoch 20/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6820 - mse: 0.4241 - mae: 0.5175
# Epoch 21/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.6800 - mse: 0.4195 - mae: 0.5147
# Epoch 22/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6739 - mse: 0.4149 - mae: 0.5120
# Epoch 23/25
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6648 - mse: 0.4100 - mae: 0.5090
# Epoch 24/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6654 - mse: 0.4054 - mae: 0.5061
# Epoch 25/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6591 - mse: 0.4010 - mae: 0.5035
# =======================================================================
# Completed 18^th Feature Map Construction Step!
# =======================================================================
# Proportion of chains remaining: 0.05...
# =======================================================================
# =======================================================================
# Performing 19^th Feature Map Construction Step!
# =======================================================================
# Epoch 1/25
# 8/8 [==============================] - 0s 12ms/step - loss: 1.9278 - mse: 0.4993 - mae: 0.5632
# Epoch 2/25
# 8/8 [==============================] - 0s 13ms/step - loss: 1.2541 - mse: 0.4929 - mae: 0.5595
# Epoch 3/25
# 8/8 [==============================] - 0s 14ms/step - loss: 0.9691 - mse: 0.4868 - mae: 0.5560
# Epoch 4/25
# 8/8 [==============================] - 0s 14ms/step - loss: 0.8147 - mse: 0.4807 - mae: 0.5525
# Epoch 5/25
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7906 - mse: 0.4745 - mae: 0.5490
# Epoch 6/25
# 8/8 [==============================] - 0s 13ms/step - loss: 0.7522 - mse: 0.4686 - mae: 0.5457
# Epoch 7/25
# 8/8 [==============================] - 0s 15ms/step - loss: 0.7458 - mse: 0.4629 - mae: 0.5424
# Epoch 8/25
# 8/8 [==============================] - 0s 27ms/step - loss: 0.7267 - mse: 0.4571 - mae: 0.5390
# Epoch 9/25
# 8/8 [==============================] - 0s 26ms/step - loss: 0.7196 - mse: 0.4513 - mae: 0.5357
# Epoch 10/25
# 8/8 [==============================] - 0s 23ms/step - loss: 0.7174 - mse: 0.4460 - mae: 0.5328
# Epoch 11/25
# 8/8 [==============================] - 0s 23ms/step - loss: 0.7098 - mse: 0.4403 - mae: 0.5295
# Epoch 12/25
# 8/8 [==============================] - 0s 22ms/step - loss: 0.7008 - mse: 0.4351 - mae: 0.5266
# Epoch 13/25
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6952 - mse: 0.4296 - mae: 0.5234
# Epoch 14/25
# 8/8 [==============================] - 0s 27ms/step - loss: 0.6910 - mse: 0.4245 - mae: 0.5203
# Epoch 15/25
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6777 - mse: 0.4195 - mae: 0.5173
# Epoch 16/25
# 8/8 [==============================] - 0s 23ms/step - loss: 0.6838 - mse: 0.4142 - mae: 0.5141
# Epoch 17/25
# 8/8 [==============================] - 0s 26ms/step - loss: 0.6673 - mse: 0.4095 - mae: 0.5113
# Epoch 18/25
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6736 - mse: 0.4043 - mae: 0.5082
# Epoch 19/25
# 8/8 [==============================] - 0s 31ms/step - loss: 0.6684 - mse: 0.3996 - mae: 0.5054
# Epoch 20/25
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6616 - mse: 0.3944 - mae: 0.5024
# Epoch 21/25
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6596 - mse: 0.3898 - mae: 0.4994
# Epoch 22/25
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6532 - mse: 0.3852 - mae: 0.4967
# Epoch 23/25
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6431 - mse: 0.3804 - mae: 0.4934
# Epoch 24/25
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6435 - mse: 0.3757 - mae: 0.4905
# Epoch 25/25
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6377 - mse: 0.3714 - mae: 0.4877
# =======================================================================
# Completed 19^th Feature Map Construction Step!
# =======================================================================
# Proportion of chains remaining: 0.0...
# =======================================================================
# NEU-Feature Map (w chaining): Saving
# NEU-Feature Map (w chaining): Saved
#                                  0
# robustness_parameter         1.086
# output_dim                   1.000
# learning_rate                0.001
# input_dim                    1.000
# implicit_dimension          20.000
# homotopy_parameter           0.000
# feature_map_height           5.000
# feature_map_depth            2.000
# epochs                      50.000
# batch_size                  32.000
# N_Trainable_Parameters  121252.000
# Feature_Depth              105.000
# N_Chains                    20.000
#                                  0
# robustness_parameter         1.086
# output_dim                   1.000
# learning_rate                0.001
# input_dim                    1.000
# implicit_dimension          20.000
# homotopy_parameter           0.000
# feature_map_height           5.000
# feature_map_depth            2.000
# epochs                      50.000
# batch_size                  32.000
# N_Trainable_Parameters  121252.000
# Feature_Depth              105.000
# N_Chains                    20.000

# %% [markdown]
# ---
# # Linear Model(s)
# ---

# %% [markdown]
# ### NEU-Linear *(decoupled implementation)*

# %%
# 2) Perform Linear Regression on Feature-Space #
#===============================================#
#====================================#
# Ordinary Linear Regression Version #
#====================================#
NEU_lin_reg = LinearRegression()
NEU_lin_reg.fit(data_x_featured_train,data_y)
NEU_OLS_train = NEU_lin_reg.predict(data_x_featured_train)
NEU_OLS_test = NEU_lin_reg.predict(data_x_featured_test)

#=====================#
# Elastic Net Version #
#=====================#
# Block warnings that spam when performing coordinate descent (by default) in 1-d.
import warnings
warnings.filterwarnings("ignore")
# Initialize Elastic Net Regularization Model
if trial_run == True: # Fast version for trial
    NEU_lin_reg = ElasticNetCV(cv=5, 
                               random_state=0, 
                               alphas = np.linspace(0,(10**2),5),
                               l1_ratio = np.linspace(0,1,5))
else: #Slow Version for real-deal
    NEU_lin_reg = ElasticNetCV(cv=5, 
                               random_state=0, 
                               alphas = np.linspace(0,(10**2),(10**2)),
                               l1_ratio=np.linspace(0,1,(10**2)))
# Fit Elastic Net Model
NEU_lin_reg.fit(data_x_featured_train,data_y)
# Out:
# ElasticNetCV(alphas=array([  0.,  25.,  50.,  75., 100.]), copy_X=True, cv=5,
#              eps=0.001, fit_intercept=True,
#              l1_ratio=array([0.  , 0.25, 0.5 , 0.75, 1.  ]), max_iter=1000,
#              n_alphas=100, n_jobs=None, normalize=False, positive=False,
#              precompute='auto', random_state=0, selection='cyclic', tol=0.0001,
#              verbose=0)

# %%
# Pre-process Linearized Data #
#=============================#
# Get Linearized Predictions #
#----------------------------#
# Produce Prediction(s)
NEU_OLS_y_hat_train = NEU_lin_reg.predict(data_x_featured_train)
NEU_OLS_y_hat_test = NEU_lin_reg.predict(data_x_featured_test)

NEU_OLS_y_hat_train_FC = NEU_OLS_train
NEU_OLS_y_hat_test_FC = NEU_OLS_test

end = time.time()

# %% [markdown]
# #### Visualization of Feature Space

# %%
print()
Embedding = pd.DataFrame(data_x_featured_test,index=data_x_test.reshape(-1,), columns=range(0,data_x_featured_test.shape[1]))
# Format Plot #
#-------------#
fig = Embedding.plot(figsize=(12, 12))
fig.get_legend().remove()
plt.title("Slices of Embedded Submanifold")
print("Embedding Dimension: " + str(data_x_featured_test.shape[1]))

# SAVE Figure to .eps
plt.savefig('./outputs/plotsANDfigures/Sliced_Manifold_Embedding_with_N_Dimensions_'+str(data_x_featured_test.shape[1])+'.pdf', format='pdf')
# Show Plot
if is_visuallty_verbose == True:
    plt.show(block=False)
# Out:
# Embedding Dimension: 42

# %% [markdown]
# #### Visual Comaprison between the OLS and the NEU-OLS models:

# %%
# Initialize Plot #
#-----------------#
fig = plt.figure(num=None, figsize=(12, 12), dpi=80, facecolor='w', edgecolor='k')

# Generate Plots #
#----------------#

# Plot Signal
plt.plot(np.array(data_x_test_raw).reshape(-1,),data_y_test,color='gray',label='f(x)',linestyle='--')
# Plot Data
plt.scatter(np.array(data_x_raw).reshape(-1,),data_y,color='gray',label='train', marker = '2')
plt.scatter(np.array(data_x_test_raw).reshape(-1,),data_y_test,color='black',label='test', marker = '.')

#----------#
# Model(s) #
#----------#
# Ordinary Linear Regression (OLS)
plt.plot(np.array(data_x_test_raw).reshape(-1,),ENET_OLS_y_hat_test, color = 'dodgerblue',linestyle=":", label='Lin. Reg')

# Plot NEU-OLS
plt.plot(np.array(data_x_test_raw).reshape(-1,),NEU_OLS_test_nochain, color = 'c',label='NEU-OLS (No Chaining)')
plt.plot(np.array(data_x_test_raw).reshape(-1,),NEU_OLS_y_hat_test_FC, color = 'red',label='NEU-OLS')
plt.plot(np.array(data_x_test_raw).reshape(-1,),ffNN_y_hat_test, color = 'purple',linestyle="--",  label='DNN')

# Format Plot #
#-------------#
plt.legend(loc="upper left")
plt.title("Model Predictions")

# Export #
#--------#
# SAVE Figure to .eps
plt.savefig('./outputs/plotsANDfigures/OLS.pdf', format='pdf')
# Show Plot
if is_visuallty_verbose == True:
    plt.show(block=False)

# %% [markdown]
# #### Error Distribution NEU-OLS

# %%
get_Error_distribution_plots(data_y_test,ENET_OLS_y_hat_test,NEU_OLS_y_hat_test_FC,"OLS")

# %% [markdown]
# #### Comparison between Elastic-Net and NEU-ENET

# %%
#-----------------#
# Linear Model(s) #
#-----------------#
# NEU-Elastic Net Performance
print("NEU-ENET Performance:")
print(reporter(NEU_OLS_y_hat_train,NEU_OLS_y_hat_test,data_y,data_y_test))


# Elastic-Net Performance
print("Elastic-Net Performance:")
print(reporter(ENET_OLS_y_hat_train,ENET_OLS_y_hat_test,data_y,data_y_test))


# ffNN
print("Benchmark: DNN (ffNN)")
print(reporter(ffNN_y_hat_train,ffNN_y_hat_test,data_y,data_y_test))


# NEU-OLS with Coupled
print("Benchmark: NEU-OLS (with Chaining)")
print(reporter(NEU_OLS_y_hat_train_FC,NEU_OLS_y_hat_test_FC,data_y,data_y_test))

# NEU-OLS No Chaining
print("Benchmark: NEU-OLS (no Chaining)")
print(reporter(NEU_OLS_train_nochain,NEU_OLS_test_nochain,data_y,data_y_test))


# Depth Used with Chaining #
print("NEU-Chained Feature Depth")
print(NEU_Feature_Depth)
# Out:
# NEU-ENET Performance:
#                  Train       Test
# Er. 95L  -6.407666e-02  -0.000241
# Er. Mean -4.055326e-08   0.005012
# Er. 95U   6.326772e-02   0.010381
# MAE       4.025262e-01   0.062349
# MSE       2.602479e-01   0.005391
# MAPE      4.512167e+02  31.920362
# Elastic-Net Performance:
#                  Train       Test
# Er. 95L  -6.302434e-02   0.003413
# Er. Mean -2.131628e-17   0.007914
# Er. 95U   6.297924e-02   0.012392
# MAE       4.033846e-01   0.049093
# MSE       2.608277e-01   0.003956
# MAPE      3.833765e+02  36.613279
# Benchmark: DNN (ffNN)
#                Train       Test
# Er. 95L    -0.054890   0.010955
# Er. Mean    0.008540   0.016968
# Er. 95U     0.071493   0.022916
# MAE         0.401552   0.070560
# MSE         0.262584   0.007279
# MAPE      567.695967  48.833845
# Benchmark: NEU-OLS (with Chaining)
#                Train       Test
# Er. 95L    -0.057582   0.061309
# Er. Mean    0.004320   0.088460
# Er. 95U     0.068161   0.116253
# MAE         0.400031   0.188730
# MSE         0.256592   0.158933
# MAPE      300.068200  62.065708
# Benchmark: NEU-OLS (no Chaining)
#                Train       Test
# Er. 95L    -0.068890   0.055158
# Er. Mean   -0.005804   0.082270
# Er. 95U     0.056465   0.111345
# MAE         0.403225   0.180741
# MSE         0.258959   0.161845
# MAPE      246.529840  54.603163
# NEU-Chained Feature Depth
# 105

# %%
print("Time to Trian NEU-OLS: "+str(end - start))
# Out:
# Time to Trian NEU-OLS: 390.04914689064026

# %% [markdown]
# ---
# # Non-Linear Models
# ---

# %% [markdown]
# ### NEU-Kernel Ridge Regression *(decoupled implementation)*

# %%
# 2) Perform Linear Regression on Feature-Space #
#===============================================#
NEU_KReg_y_hat_train_pre,NEU_KReg_y_hat_test_pre, NEU_KReg_model = get_Kernel_Ridge_Regressor(data_x_in = data_x_featured_train,
                                                                                       data_x_test_in = data_x_featured_test,
                                                                                       data_y_in = data_y)


NEU_KReg_y_hat_train = NEU_KReg_y_hat_train_pre
NEU_KReg_y_hat_test = NEU_KReg_y_hat_test_pre
# Out:
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   2 out of   2 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=3)]: Done   2 out of   2 | elapsed:    0.8s finished

# %% [markdown]
# #### Visual Comaprison between the Kernel Ridge Regression and the NEU-Kernel Ridge Regression models:

# %%
# Initialize Plot #
#-----------------#
fig = plt.figure(num=None, figsize=(12, 12), dpi=80, facecolor='w', edgecolor='k')

# Generate Plots #
#----------------#

# Plot Signal
plt.plot(np.array(data_x_test_raw).reshape(-1,),data_y_test,color='gray',label='f(x)',linestyle='--')
# Plot Data
plt.scatter(np.array(data_x_raw).reshape(-1,),data_y,color='gray',label='train', marker = '2')
plt.scatter(np.array(data_x_test_raw).reshape(-1,),data_y_test,color='black',label='test', marker = '.')

#----------#
# Model(s) #
#----------#
# Kernel Ridge Regressor
plt.plot(np.array(data_x_test_raw).reshape(-1,),f_hat_kernel_ridge_test,color='violet',linestyle="--",label='Kernel Ridge')
# NEU-Kernel Ridge Regressor
plt.plot(np.array(data_x_test_raw).reshape(-1,),NEU_KReg_y_hat_test,color='darkviolet',label='NEU-Kernel Ridge')

# Format Plot #
#-------------#
plt.legend(loc="upper left")
plt.title("Model Predictions")

# Export #
#--------#
# SAVE Figure to .eps
plt.savefig('./outputs/plotsANDfigures/Kernel_Ridge.pdf', format='pdf')
# Show Plot
if is_visuallty_verbose == True:
    plt.show(block=False)

# %%
get_Error_distribution_plots(data_y_test,f_hat_kernel_ridge_test,NEU_KReg_y_hat_test,"Kernel_Ridge")

# %% [markdown]
# #### Numerical Comparison between the Kernel Ridge regressor and NEU-Kernel Ridge regressor models:

# %%
#-----------------------#
# Kernel Ridge Model(s) #
#-----------------------#
# Kernel Ridge Performance
print("Kernel Ridge-Performance:")
print(reporter(f_hat_kernel_ridge_train,f_hat_kernel_ridge_test,data_y,data_y_test))

# NEU-Kernel Ridge Performance
print("NEU-Kernel Ridge-Performance:")
print(reporter(NEU_KReg_y_hat_train,NEU_KReg_y_hat_test,data_y,data_y_test))
# Out:
# Kernel Ridge-Performance:
#                  Train       Test
# Er. 95L  -6.197173e-02   0.003948
# Er. Mean -4.077463e-07   0.008932
# Er. 95U   6.211305e-02   0.013900
# MAE       4.007924e-01   0.062981
# MSE       2.580143e-01   0.004993
# MAPE      4.149705e+02  33.352105
# NEU-Kernel Ridge-Performance:
#                Train       Test
# Er. 95L    -0.064056   0.011751
# Er. Mean   -0.000005   0.019163
# Er. 95U     0.061774   0.026531
# MAE         0.398876   0.071813
# MSE         0.254849   0.011031
# MAPE      409.248298  35.756205

# %% [markdown]
# ## Tree Model(s):
# *Naturally, all of these have a decoupled implementation*.

# %%
# 2) Perform Linear Regression on Feature-Space #
#===============================================#
NEU_GBRF_y_hat_train_pre,NEU_GBRF_y_hat_test_pre, GBRF_w_NEU_features = get_GBRF(X_train = data_x_featured_train,
                                                                                 X_test = data_x_featured_test,
                                                                                 y_train = data_y)

NEU_GBRF_y_hat_train = NEU_GBRF_y_hat_train_pre
NEU_GBRF_y_hat_test = NEU_GBRF_y_hat_test_pre
# Out:
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   2 out of   2 | elapsed:    1.6s remaining:    0.0s
# [Parallel(n_jobs=3)]: Done   2 out of   2 | elapsed:    1.6s finished

# %% [markdown]
# #### Visual Comaprison between the GBRF and the NEU-GBRF models:

# %%
# Initialize Plot #
#-----------------#
plt.figure(num=None, figsize=(12, 12), dpi=80, facecolor='w', edgecolor='k')

# Generate Plots #
#----------------#

# Plot Signal
plt.plot(np.array(data_x_test_raw).reshape(-1,),data_y_test,color='gray',label='f(x)',linestyle='--')
# Plot Data
plt.scatter(np.array(data_x_raw).reshape(-1,),data_y,color='gray',label='train', marker = '2')
plt.scatter(np.array(data_x_test_raw).reshape(-1,),data_y_test,color='black',label='test', marker = '.')

#----------#
# Model(s) #
#----------#
# Plot Gradient-Boosted Random Forest Regressor (GBRF):
plt.plot(np.array(data_x_test_raw).reshape(-1,),GBRF_y_hat_test, linestyle="--", color = 'forestgreen', label='GBRF')
# Plot NEU-GBRF:
plt.plot(np.array(data_x_test_raw).reshape(-1,),NEU_GBRF_y_hat_test, color = 'blue',label='NEU-GBRF')


# Format Plot #
#-------------#
plt.legend(loc="upper left")
plt.title("Model Predictions")


# Export #
#--------#
# SAVE Figure to .eps
plt.savefig('./outputs/plotsANDfigures/GBRF.pdf', format='pdf')
# Show Plot
if is_visuallty_verbose == True:
    plt.show(block=False)

# %%
get_Error_distribution_plots(data_y_test,GBRF_y_hat_test,NEU_GBRF_y_hat_test,"GBRF")

# %% [markdown]
# #### Numerical Comparison between the GBRF and NEU-GBRF models:

# %%
#---------------#
# Tree Model(s) #
#---------------#
# GBRF Performance
print("GBRF-Performance:")
print(reporter(GBRF_y_hat_train,GBRF_y_hat_test,data_y,data_y_test))

# NEU-GBRF Performance
print("NEU-GBRF-Performance:")
print(reporter(NEU_GBRF_y_hat_train,NEU_GBRF_y_hat_test,data_y,data_y_test))
# Out:
# GBRF-Performance:
#                  Train        Test
# Er. 95L  -5.777863e-02   -0.025606
# Er. Mean -5.684342e-17   -0.011706
# Er. 95U   5.648242e-02    0.002264
# MAE       3.675658e-01    0.156995
# MSE       2.133696e-01    0.039118
# MAPE      3.631001e+02  122.547501
# NEU-GBRF-Performance:
#                  Train        Test
# Er. 95L  -5.393225e-02   -0.024958
# Er. Mean -2.131628e-17   -0.009294
# Er. 95U   5.290854e-02    0.006546
# MAE       3.482599e-01    0.186168
# MSE       1.898665e-01    0.049269
# MAPE      2.376811e+02  171.290078

# %% [markdown]
# ---
# ## Neural Networks:
# ---
# ### NEU-ffNN

# %% [markdown]
# #### A) Fully-Coupled Implementation
# - Train feature-map + ffNN ($\hat{f}\circ \phi$) in one go.

# %%
# tf.random.set_seed(2020)
# NEU_ffNN_y_hat_train, NEU_ffNN_y_hat_test = build_NEU_ffNN_w_feature_only(n_folds = CV_folds, 
#                                                                           n_jobs = n_jobs, 
#                                                                           n_iter = n_iter, 
#                                                                           param_grid_in = param_grid_NEU_Nets, 
#                                                                           X_train = data_x, 
#                                                                           y_train = data_y,
#                                                                           X_test = data_x_test)

# %% [markdown]
# #### B) Decoupled NEU-ffNN

# %%
tf.random.set_seed(2020)
NEU_ffNN_y_hat_train, NEU_ffNN_y_hat_test = build_ffNN(n_folds = CV_folds, 
                                                       n_jobs = n_jobs, 
                                                       n_iter = n_iter, 
                                                       param_grid_in = param_grid_Vanilla_Nets, 
                                                       X_train = data_x_featured_train, 
                                                       y_train = data_y,
                                                       X_test = data_x_featured_test)
# Out:
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   2 out of   2 | elapsed:    5.2s remaining:    0.0s
# [Parallel(n_jobs=3)]: Done   2 out of   2 | elapsed:    5.2s finished
# Epoch 1/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4510 - mse: 0.3167 - mae: 0.4510 - mape: 250.6762
# Epoch 2/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4248 - mse: 0.2948 - mae: 0.4248 - mape: 405.5311
# Epoch 3/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4073 - mse: 0.2646 - mae: 0.4073 - mape: 281.0642
# Epoch 4/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4069 - mse: 0.2652 - mae: 0.4069 - mape: 261.1076
# Epoch 5/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4030 - mse: 0.2630 - mae: 0.4030 - mape: 309.8690
# Epoch 6/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4045 - mse: 0.2631 - mae: 0.4045 - mape: 320.6620
# Epoch 7/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4028 - mse: 0.2613 - mae: 0.4028 - mape: 312.8739
# Epoch 8/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4045 - mse: 0.2632 - mae: 0.4045 - mape: 332.4322
# Epoch 9/200
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4074 - mse: 0.2660 - mae: 0.4074 - mape: 291.7684
# Epoch 10/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4038 - mse: 0.2630 - mae: 0.4038 - mape: 265.8162
# Epoch 11/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4040 - mse: 0.2629 - mae: 0.4040 - mape: 298.5151
# Epoch 12/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4036 - mse: 0.2622 - mae: 0.4036 - mape: 316.6217
# Epoch 13/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4054 - mse: 0.2626 - mae: 0.4054 - mape: 307.0144
# Epoch 14/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4027 - mse: 0.2619 - mae: 0.4027 - mape: 300.2775
# Epoch 15/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4042 - mse: 0.2650 - mae: 0.4042 - mape: 292.3802
# Epoch 16/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4036 - mse: 0.2640 - mae: 0.4036 - mape: 265.3503
# Epoch 17/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4037 - mse: 0.2636 - mae: 0.4037 - mape: 285.2954
# Epoch 18/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4029 - mse: 0.2622 - mae: 0.4029 - mape: 288.4667
# Epoch 19/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4039 - mse: 0.2642 - mae: 0.4039 - mape: 305.2540
# Epoch 20/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4032 - mse: 0.2629 - mae: 0.4032 - mape: 278.5427
# Epoch 21/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4024 - mse: 0.2620 - mae: 0.4024 - mape: 270.4236
# Epoch 22/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4038 - mse: 0.2646 - mae: 0.4038 - mape: 299.8649
# Epoch 23/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4033 - mse: 0.2638 - mae: 0.4033 - mape: 287.4706
# Epoch 24/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.
plt.plot(np.array(data_x_test_raw).reshape(-1,),data_y_test,color='gray',label='f(x)',linestyle='--')
# Plot Data
plt.scatter(np.array(data_x_raw).reshape(-1,),data_y,color='gray',label='train', marker = '2')
plt.scatter(np.array(data_x_test_raw).reshape(-1,),data_y_test,color='black',label='test', marker = '.')

#--------------------#
# Benchmark Model(s) #
#--------------------#
# Plot ffNN
plt.plot(np.array(data_x_test_raw).reshape(-1,),ffNN_y_hat_test, color = 'blue',linestyle="--",  label='DNN')


#--------------#
# NEU-Model(s) #
#--------------#
# Plot NEU-ffNN (Training Variants)
plt.plot(np.array(data_x_test_raw).reshape(-1,),NEU_ffNN_y_hat_test, linestyle=":", color = 'darkgreen',label='DNN_NEU_coupled')



# Format Plot #
#-------------#
plt.legend(loc="upper left")
plt.title("Model Predictions")

# Export #
#--------#
# SAVE Figure to .eps
plt.savefig('./outputs/plotsANDfigures/Neural_Network_Models.pdf', format='pdf')
# Show Plot
if is_visuallty_verbose == True:
    plt.show(block=False)

# %%
get_Error_distribution_plots(data_y_test,ffNN_y_hat_test,NEU_ffNN_y_hat_test,"ffNN")

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ---
# # Result(s)
# ---

# %% [markdown]
# ## Generate Results Table(s):

# %%
#=========#
# Testing #
#=========#
test_performance  = pd.DataFrame({"Smoothin Splines": reporter(f_hat_smoothing_splines_train,f_hat_smoothing_splines_test,data_y,data_y_test).iloc[:,0],
                                   "LOESS": reporter(LOESS_prediction_train,LOESS_prediction_test,data_y,data_y_test).iloc[:,0],
                                   "Elastic Net": reporter(ENET_OLS_y_hat_train,ENET_OLS_y_hat_test,data_y,data_y_test).iloc[:,0],
                                   "NEU-OLS": reporter(NEU_OLS_y_hat_train_FC,NEU_OLS_y_hat_test_FC,data_y,data_y_test).iloc[:,0],
                                   "NEU-OLS (no chain)": reporter(NEU_OLS_train_nochain,NEU_OLS_test_nochain,data_y,data_y_test).iloc[:,0],
                                   "NEU-ENET": reporter(NEU_OLS_y_hat_train,NEU_OLS_y_hat_test,data_y,data_y_test).iloc[:,0],
                                   "Kernel": reporter(f_hat_kernel_ridge_train,f_hat_kernel_ridge_test,data_y,data_y_test).iloc[:,0],
                                   "NEU-KerRidge": reporter(NEU_KReg_y_hat_train,NEU_KReg_y_hat_test,data_y,data_y_test).iloc[:,0],
                                   "GBRF": reporter(GBRF_y_hat_train,GBRF_y_hat_test,data_y,data_y_test).iloc[:,0],
                                   "NEU-GBRF": reporter(NEU_GBRF_y_hat_train,NEU_GBRF_y_hat_test,data_y,data_y_test).iloc[:,0],
                                   "ffNN": reporter(ffNN_y_hat_train,ffNN_y_hat_test,data_y,data_y_test).iloc[:,0],
                                   "NEU-ffNN (Coupled)": reporter(NEU_ffNN_y_hat_train,NEU_ffNN_y_hat_test,data_y,data_y_test).iloc[:,0]}).transpose()


test_performance.to_latex("./outputs/tables/Test_performance.tex")

#==========#
# Training #
#==========#
train__performance  = pd.DataFrame({"Smoothin Splines": reporter(f_hat_smoothing_splines_train,f_hat_smoothing_splines_test,data_y,data_y_test).iloc[:,1],
                                   "LOESS": reporter(LOESS_prediction_train,LOESS_prediction_test,data_y,data_y_test).iloc[:,1],
                                   "Elastic Net": reporter(ENET_OLS_y_hat_train,ENET_OLS_y_hat_test,data_y,data_y_test).iloc[:,1],
                                   "NEU-OLS": reporter(NEU_OLS_y_hat_train_FC,NEU_OLS_y_hat_test_FC,data_y,data_y_test).iloc[:,1],
                                    "NEU-OLS (no chain)": reporter(NEU_OLS_train_nochain,NEU_OLS_test_nochain,data_y,data_y_test).iloc[:,1],
                                   "NEU-ENET": reporter(NEU_OLS_y_hat_train,NEU_OLS_y_hat_test,data_y,data_y_test).iloc[:,1],
                                   "Kernel": reporter(f_hat_kernel_ridge_train,f_hat_kernel_ridge_test,data_y,data_y_test).iloc[:,1],
                                   "NEU-KerRidge": reporter(NEU_KReg_y_hat_train,NEU_KReg_y_hat_test,data_y,data_y_test).iloc[:,1],
                                   "GBRF": reporter(GBRF_y_hat_train,GBRF_y_hat_test,data_y,data_y_test).iloc[:,1],
                                   "NEU-GBRF": reporter(NEU_GBRF_y_hat_train,NEU_GBRF_y_hat_test,data_y,data_y_test).iloc[:,1],
                                   "ffNN": reporter(ffNN_y_hat_train,ffNN_y_hat_test,data_y,data_y_test).iloc[:,1],
                                   "NEU-ffNN (Coupled)": reporter(NEU_ffNN_y_hat_train,NEU_ffNN_y_hat_test,data_y,data_y_test).iloc[:,1]}).transpose()

train__performance.to_latex("./outputs/tables/Train_performance.tex")

# %% [markdown]
# # Visualize Predictions

# %%
# Initialize Plot #
#-----------------#
plt.figure(num=None, figsize=(14, 14), dpi=80, facecolor='w', edgecolor='k')

# Generate Plots #
#----------------#

# Plot Signal
plt.plot(np.array(data_x_test_raw).reshape(-1,),data_y_test,color='gray',label='f(x)',linestyle='--')
# Plot Data
plt.scatter(np.array(data_x_raw).reshape(-1,),data_y,color='gray',label='train', marker = '2')
plt.scatter(np.array(data_x_test_raw).reshape(-1,),data_y_test,color='black',label='test', marker = '.')

#--------------------#
# Benchmark Model(s) #
#--------------------#
# Ordinary Linear Regression (OLS)
plt.plot(np.array(data_x_test_raw).reshape(-1,),ENET_OLS_y_hat_test, color = 'dodgerblue',linestyle=":", label='Lin. Reg')
# Plot Gradient-Boosted Random Forest Regressor (GBRF):
plt.plot(np.array(data_x_test_raw).reshape(-1,),GBRF_y_hat_test, color = 'forestgreen',linestyle=":", label='GBRF')
# Plot Non-Linar Benchmark(s): Classical
plt.plot(np.array(data_x_test_raw).reshape(-1,),f_hat_smoothing_splines_test,color='grey',linestyle="--",label='Splines')
plt.plot(np.array(data_x_test_raw).reshape(-1,),LOESS_prediction_test,color='purple',linestyle="--",label='LOESS')
# Kernel Ridge Regressor
plt.plot(np.array(data_x_test_raw).reshape(-1,),f_hat_kernel_ridge_test,color='violet',linestyle="--",label='Kernel Ridge')
# Plot ffNN
plt.plot(np.array(data_x_test_raw).reshape(-1,),ffNN_y_hat_test, color = 'blue',linestyle="--",  label='DNN')


#--------------#
# NEU-Model(s) #
#--------------#
# Plot NEU-OLS
plt.plot(np.array(data_x_test_raw).reshape(-1,),NEU_OLS_y_hat_test_FC, color = 'c',label='NEU_OLS')
# Plot NEU-GBRF:
plt.plot(np.array(data_x_test_raw).reshape(-1,),NEU_GBRF_y_hat_test, color = 'forestgreen',label='NEU-GBRF')
# NEU-Kernel Ridge Regressor
plt.plot(np.array(data_x_test_raw).reshape(-1,),NEU_KReg_y_hat_test,color='darkviolet',label='NEU-Kernel Ridge')
# Plot NEU-ffNN (Training Variants)
plt.plot(np.array(data_x_test_raw).reshape(-1,),NEU_ffNN_y_hat_test, linestyle=":", color = 'red',label='DNN_NEU_coupled')


# Format Plot #
#-------------#
plt.legend(loc="upper left")
plt.title("Model Predictions")

# Export #
#--------#
# SAVE Figure to .eps
plt.savefig('./outputs/plotsANDfigures/Full_Picture.pdf', format='pdf')
# Show Plot
if is_visuallty_verbose == True:
    plt.show(block=False)

# %% [markdown]
#  ---

# %% [markdown]
# ## Performance Report
# - First, we print the comparison tables (so it can be viewed from the command-line if it is being run live on a grid/cluster/remotely).
# - Second, we display the training and testing performances in clean dataframes.

# %%
#--------------------#
# Classical Model(s) #
#--------------------#
# OLS Performance
print("OLS-Performance:")
# print(reporter(OLS_y_hat_train,OLS_y_hat_test,data_y,data_y_test))

# NEU-OLS Performance
print("NEU-OLS-Performance:")
print(reporter(NEU_OLS_y_hat_train,NEU_OLS_y_hat_test,data_y,data_y_test))
# Out:
# OLS-Performance:
# NEU-OLS-Performance:
#                  Train       Test
# Er. 95L  -6.236224e-02  -0.000301
# Er. Mean -4.055326e-08   0.005012
# Er. 95U   6.324897e-02   0.010214
# MAE       4.025262e-01   0.062349
# MSE       2.602479e-01   0.005391
# MAPE      4.512167e+02  31.920362

# %%
#-----------------------#
# Kernel Ridge Model(s) #
#-----------------------#
# Kernel Ridge Performance
print("Kernel Ridge-Performance:")
print(reporter(f_hat_kernel_ridge_train,f_hat_kernel_ridge_test,data_y,data_y_test))

# NEU-Kernel Ridge Performance
print("NEU-Kernel Ridge-Performance:")
print(reporter(NEU_KReg_y_hat_train,NEU_KReg_y_hat_test,data_y,data_y_test))
# Out:
# Kernel Ridge-Performance:
#                  Train       Test
# Er. 95L  -6.214596e-02   0.003921
# Er. Mean -4.077463e-07   0.008932
# Er. 95U   6.259222e-02   0.013955
# MAE       4.007924e-01   0.062981
# MSE       2.580143e-01   0.004993
# MAPE      4.149705e+02  33.352105
# NEU-Kernel Ridge-Performance:
#                Train       Test
# Er. 95L    -0.064268   0.011574
# Er. Mean   -0.000005   0.019163
# Er. 95U     0.062768   0.026576
# MAE         0.398876   0.071813
# MSE         0.254849   0.011031
# MAPE      409.248298  35.756205

# %%
#---------------#
# Tree Model(s) #
#---------------#
# GBRF Performance
print("GBRF-Performance:")
print(reporter(GBRF_y_hat_train,GBRF_y_hat_test,data_y,data_y_test))

# NEU-GBRF Performance
print("NEU-GBRF-Performance:")
print(reporter(NEU_GBRF_y_hat_train,NEU_GBRF_y_hat_test,data_y,data_y_test))
# Out:
# GBRF-Performance:
#                  Train        Test
# Er. 95L  -5.820034e-02   -0.025831
# Er. Mean -5.684342e-17   -0.011706
# Er. 95U   5.720741e-02    0.002517
# MAE       3.675658e-01    0.156995
# MSE       2.133696e-01    0.039118
# MAPE      3.631001e+02  122.547501
# NEU-GBRF-Performance:
#                  Train        Test
# Er. 95L  -5.352561e-02   -0.025090
# Er. Mean -2.131628e-17   -0.009294
# Er. 95U   5.427255e-02    0.006292
# MAE       3.482599e-01    0.186168
# MSE       1.898665e-01    0.049269
# MAPE      2.376811e+02  171.290078

# %%
#-----------------------------------------------------#
# Classical Non-Linear Univariate Regression Model(s) #
#-----------------------------------------------------#
# Splines Performance
print("Splines-Performance:")
print(reporter(f_hat_smoothing_splines_train,f_hat_smoothing_splines_test,data_y,data_y_test))

# Loess Performance
print("LOESS Performance:")
print(reporter(LOESS_prediction_train,LOESS_prediction_test,data_y,data_y_test))
# Out:
# Splines-Performance:
#                  Train        Test
# Er. 95L  -6.112612e-02   -0.003705
# Er. Mean  7.182432e-14    0.003456
# Er. 95U   6.005821e-02    0.010617
# MAE       3.890914e-01    0.077688
# MSE       2.426262e-01    0.009650
# MAPE      5.103997e+02  139.970001
# LOESS Performance:
#                Train      Test
# Er. 95L    -0.074521  0.002380
# Er. Mean   -0.011883  0.011159
# Er. 95U     0.051285  0.020243
# MAE         0.402041  0.071406
# MSE         0.260567  0.015937
# MAPE      802.217775       inf

# %%
#--------------#
# DNN Model(s) #
#--------------#
# ffNN Performance
print("ffNN-Performance:")
print(reporter(ffNN_y_hat_train,ffNN_y_hat_test,data_y,data_y_test))

# NEU-ffNN Performance
print("NEU-ffNN (Coupled) Performance:") #Readout Form!
print(reporter(NEU_ffNN_y_hat_train,NEU_ffNN_y_hat_test,data_y,data_y_test))

# print("NEU-ffNN (Decoupled) Performance:")
# print(reporter(NEU_ffNN_y_hat_train_Dcpld,NEU_ffNN_y_hat_test_Dcpld,data_y,data_y_test))
# Out:
# ffNN-Performance:
#                Train       Test
# Er. 95L    -0.055643   0.010975
# Er. Mean    0.008540   0.016968
# Er. 95U     0.072254   0.022777
# MAE         0.401552   0.070560
# MSE         0.262584   0.007279
# MAPE      567.695967  48.833845
# NEU-ffNN (Coupled) Performance:
#                Train       Test
# Er. 95L    -0.060265   0.005466
# Er. Mean    0.003580   0.012143
# Er. 95U     0.067534   0.018525
# MAE         0.401360   0.075001
# MSE         0.263289   0.008551
# MAPE      890.786763  48.817804

# %% [markdown]
# # Report

# %% [markdown]
# ## Re-Summarize Learning Problem for easy recap :)

# %%
print("Simulation Confiugration Information:")
print(" ")
print("=========================================================================================================================================================")
print(the_facts)
print("=========================================================================================================================================================")
print(" ")
# Out:
# Simulation Confiugration Information:
#
# =========================================================================================================================================================
# We're plotting the function: nonlocality with 0.5 additive noise, a distortion/model uncertainty level of 0.5, and an out-of sample window on either side of the input space of: 0.001.  We train using 1000 datapoints and have a test set conisting of 0.75% percent of the total generated data.
# =========================================================================================================================================================

# %% [markdown]
# ## Train-Set Performance

# %%
train__performance
# Out:
#                      Er. 95L  Er. Mean   Er. 95U       MAE       MSE  \
# Smoothin Splines   -0.003564  0.003456  0.010379  0.077688  0.009650
# LOESS               0.002437  0.011159  0.020191  0.071406  0.015937
# Elastic Net         0.003413  0.007914  0.012307  0.049093  0.003956
# NEU-OLS             0.061047  0.088460  0.116761  0.188730  0.158933
# NEU-OLS (no chain)  0.054491  0.082270  0.110566  0.180741  0.161845
# NEU-ENET           -0.000201  0.005012  0.010248  0.062349  0.005391
# Kernel              0.003840  0.008932  0.013922  0.062981  0.004993
# NEU-KerRidge        0.011739  0.019163  0.026545  0.071813  0.011031
# GBRF               -0.025484 -0.011706  0.002642  0.156995  0.039118
# NEU-GBRF           -0.025503 -0.009294  0.006302  0.186168  0.049269
# ffNN                0.011035  0.016968  0.022853  0.070560  0.007279
# NEU-ffNN (Coupled)  0.005484  0.012143  0.018553  0.075001  0.008551
#
#                           MAPE
# Smoothin Splines    139.970001
# LOESS                      inf
# Elastic Net          36.613279
# NEU-OLS              62.065708
# NEU-OLS (no chain)   54.603163
# NEU-ENET             31.920362
# Kernel               33.352105
# NEU-KerRidge         35.756205
# GBRF                122.547501
# NEU-GBRF            171.290078
# ffNN                 48.833845
# NEU-ffNN (Coupled)   48.817804

# %% [markdown]
# ## Test-Set Performance

# %%
test_performance
# Out:
#                      Er. 95L      Er. Mean   Er. 95U       MAE       MSE  \
# Smoothin Splines   -0.059986  7.182432e-14  0.060619  0.389091  0.242626
# LOESS              -0.075081 -1.188294e-02  0.052254  0.402041  0.260567
# Elastic Net        -0.062821 -2.131628e-17  0.064155  0.403385  0.260828
# NEU-OLS            -0.057679  4.319830e-03  0.065838  0.400031  0.256592
# NEU-OLS (no chain) -0.068685 -5.804193e-03  0.057786  0.403225  0.258959
# NEU-ENET           -0.062162 -4.055326e-08  0.064306  0.402526  0.260248
# Kernel             -0.062172 -4.077463e-07  0.061357  0.400792  0.258014
# NEU-KerRidge       -0.064170 -4.756293e-06  0.063960  0.398876  0.254849
# GBRF               -0.057798 -5.684342e-17  0.056286  0.367566  0.213370
# NEU-GBRF           -0.053581 -2.131628e-17  0.054008  0.348260  0.189866
# ffNN               -0.054909  8.539933e-03  0.071546  0.401552  0.262584
# NEU-ffNN (Coupled) -0.060796  3.579684e-03  0.067377  0.401360  0.263289
#
#                           MAPE
# Smoothin Splines    510.399716
# LOESS               802.217775
# Elastic Net         383.376533
# NEU-OLS             300.068200
# NEU-OLS (no chain)  246.529840
# NEU-ENET            451.216737
# Kernel              414.970514
# NEU-KerRidge        409.248298
# GBRF                363.100060
# NEU-GBRF            237.681144
# ffNN                567.695967
# NEU-ffNN (Coupled)  890.786763

# %% [markdown]
# ## About the NEU-Feature Map

# %%
NEU_Feature_Map_w_Chaining
# Out:
#                                  0
# robustness_parameter         1.086
# output_dim                   1.000
# learning_rate                0.001
# input_dim                    1.000
# implicit_dimension          20.000
# homotopy_parameter           0.000
# feature_map_height           5.000
# feature_map_depth            2.000
# epochs                      50.000
# batch_size                  32.000
# N_Trainable_Parameters  121252.000
# Feature_Depth              105.000
# N_Chains                    20.000

# %% [markdown]
# #### The END

# %% [markdown]
# ---
